# %% [markdown]
# <a href="https://colab.research.google.com/github/ansar-mazhar/Iris-Flower-Classification/blob/main/Iris_Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Iris Flower Classification

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Load DataSet

# %%
path = r"/content/Iris.csv"
df = pd.read_csv(path)

# %% [markdown]
# # Data Cleansing

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# #Splitting DataSet into Training and Test Data

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:,:-1]
y = df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Model Selection

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
tree_model = DecisionTreeClassifier(max_depth=2)
param_grid = {
    'max_depth': [2, 3, 4, 5, None],  # Depth of tree
    'criterion': ['gini', 'entropy'],  # Splitting criteria
    'min_samples_split': [2, 5, 10]  # Minimum samples required to split a node
}
cv = GridSearchCV(tree_model,param_grid=param_grid,cv=5,scoring='accuracy')
cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(max_depth=2),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5, None],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
y_pred = cv.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report
score = accuracy_score(y_pred, y_test)
print("Required Machine Learning Model has",score*100, "% accuracy score")
# Out:
# Required Machine Learning Model has 100.0 % accuracy score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

recall = recall_score(y_test, y_pred)
print("Recall:", recall)

f1 = f1_score(y_test, y_pred)
print("F1 Score:", f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3780688020.py in <cell line: 0>()
#       1 from sklearn.metrics import precision_score, recall_score, f1_score
# ----> 2 precision = precision_score(y_test, y_pred)
#       3 print("Precision:", precision)
#       4
#       5 recall = recall_score(y_test, y_pred)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
# ...

# %%
counts = df['Species'].value_counts()
counts
